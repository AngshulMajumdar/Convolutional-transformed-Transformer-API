# %% [markdown]
# # Transformed Transformer API showcase
#
# This notebook is meant for recruiter or interviewer demos.

# %%
from transformed_transformer import ModelConfig, build_tiny_classifier, build_mini_bert_classifier, build_mini_slm
tiny = build_tiny_classifier(ModelConfig(vocab_size=32, seq_len=12, attention_type='standard'))
bert = build_mini_bert_classifier(ModelConfig(vocab_size=64, seq_len=16, attention_type='transformed_dense'))
slm = build_mini_slm(ModelConfig(vocab_size=64, seq_len=16, attention_type='transformed_sparse'))
type(tiny).__name__, type(bert).__name__, type(slm).__name__
